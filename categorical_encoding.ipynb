# %% [markdown]
# <a href="https://colab.research.google.com/github/OG810/Machine-Learning-Algorithms/blob/main/categorical_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# encoding the categorical data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/customer.csv')
print(df)
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
df.sample(5)
# Out:
#      review education purchased
# 29  Average        UG       Yes
# 4   Average        UG        No
# 10     Good        UG       Yes
# 43     Poor        PG        No
# 18     Good    School        No

# %%
df=df.iloc[:,2:]
df.head()
# Out:
#   purchased
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No

# %% [markdown]
# here indexing in dataset is done and is done according to this : 0th index=col1 age, 1st index=col2 gender, 2nd index=col3 review, 3rd index=col4 education , 4rth index=col5 purchased ..... so here according to iloc and its passes paramerters all the colums will printed from 2nd index onwards till last ie 4rth index

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test=train_test_split(df.iloc[:,0:2],df.iloc[:,-1,],test_size=0.2)
## here we created the training and the testing dataset. my x parameter ie input will age,review,education columns and my y paramert ie
## output wala column will have purchased. Age in nominal data and [review,education] will have ordinal data as cpmarision will be done.
## age column will be one hot coding , review,education]columns will have ordinal coding and purchased will have label encoding.
## Now for this time ignore one hot encoding. so will extract only review and education as input columns. for that training dataset is passed
## with iloc parameters for x parameter[:,0:2] ie only review and education y parameter last column -1.


from sklearn.preprocessing import OrdinalEncoder

x_train
# Out:
#    purchased
# 30        No
# 9        Yes
# 4         No
# 42       Yes
# 48       Yes
# 8         No
# 45       Yes
# 25        No
# 29       Yes
# 28        No
# 27        No
# 40        No
# 23        No
# 24       Yes
# 26        No
# 20       Yes
# 46        No
# 36       Yes
# 15        No
# 19       Yes
# 5        Yes
# 10       Yes
# 39        No
# 18        No
# 16       Yes
# 21        No
# 33       Yes
# 22       Yes
# 44        No
# 31       Yes
# 14       Yes
# 34        No
# 12        No
# 13        No
# 17       Yes
# 2         No
# 32       Yes
# 1         No
# 38        No
# 49        No

# %% [markdown]
# oe=OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])
# oe.fit(x_train)
#
# ## here we created the object oe of ordinal encoder and the training dataset ie x_train is fitted in that object and later we transform
# ## it on the testing dataset also as shown below
#
# x_train = oe.transform(x_train)
# x_test=oe.transform(x_test)
# x_train
